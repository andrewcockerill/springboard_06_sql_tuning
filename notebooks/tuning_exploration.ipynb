# %% [markdown]
# #### SQL Tuning Exploration

# %%
# Packages
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import text
from sqlalchemy.orm import sessionmaker
import os
from dotenv import load_dotenv
import logging
import re

# %%
# Constants
load_dotenv("../src/.env")
DB_USER = os.getenv("DB_USER")
DB_NAME = "dblp"
DB_PASSWORD = os.getenv("DB_PASSWORD")
HOST = os.getenv("HOST")
PORT = os.getenv("PORT")
CONNECT_STRING = f"postgresql://{DB_USER}:{DB_PASSWORD}@{HOST}:{PORT}/{DB_NAME}"
SQL_CODE = "../src/sql_tuning_testing.sql"

# Settings
pd.set_option('display.max_colwidth', None)

# Engine
engine = create_engine(CONNECT_STRING)
Session = sessionmaker(engine)

# %%
# Parse query into a dictionary of dictionaries with keys (Question, Query, Indexes, Cleanup)
parsed_query = {f"P{k+1}":v for k,v in 
                enumerate([{re.sub(r"^/\*(\w+):[\S\s]*", r"\1",i):re.sub(r"\*/","",re.sub(r"^.*:\*/\n|^.*: ", "",i)) for i in j} for j in test])}

# %%
def indexing_experiment(question_num):
    """Helper function to iterate through parsed SQL code to run each query, evaluate performance with/without indices, and
    cleanup."""
    context = parsed_query[question_num]
    # Show Question
    print(context['Question'])

    # Show query result
    print("Query Result (First 5 rows)")
    display(pd.read_sql(context['Query'], engine).head())

    # Explain results before indexing
    print('EXPLAIN results')
    display(pd.read_sql("EXPLAIN (ANALYZE,BUFFERS) " + context['Query'], engine))

    # Run indexing
    with Session() as session:
        session.execute(text(context['Indexing']))
        session.commit()

    # Re-run Explain
    print('EXPLAIN results')
    display(pd.read_sql("EXPLAIN (ANALYZE,BUFFERS) " + context['Query'], engine))

    # Cleanup indexes
    with Session() as session:
        session.execute(text(context['Cleanup']))
        session.commit()

# %% [markdown]
# ##### Question 1:
# We can see that

# %%
indexing_experiment("P1")
# Out:
# Write a SQL Query to find all the conferences held in 2018 that have published at least 200 papers in a single decade.
#
#
# Query Result (First 5 rows)
#   booktitle
# 0    COLINS
# 1   ICL (2)
# 2   CBI (1)
# 3     ICSOC
# 4        FG
# EXPLAIN results
#                                                                                                                                                                        QUERY PLAN
# 0                                                                  HashAggregate  (cost=609916.11..609918.11 rows=200 width=8) (actual time=1527.338..1527.457 rows=1456 loops=1)
# 1                                                                                                                                                        Group Key: inp.booktitle
# 2                                                                                                                                                 Batches: 1  Memory Usage: 145kB
# 3                                                                                                                                           Buffers: shared hit=31928 read=133286
# 4                                                          ->  HashAggregate  (cost=549876.72..608476.32 rows=115183 width=48) (actual time=1526.077..1526.970 rows=2691 loops=1)
# 5                                                                                                                                Group Key: inp.booktitle, substr(inp.year, 3, 1)
# 6                                                                                                                                                       Filter: (count(*) >= 200)
# 7                                                                                                                         Planned Partitions: 8  Batches: 1  Memory Usage: 2065kB
# 8                                                                                                                                                    Rows Removed by Filter: 3890
# 9                                                                                                                                           Buffers: shared hit=31928 read=133286
# 10                                                          ->  Hash Join  (cost=104003.38..238881.27 rows=3455505 width=40) (actual time=272.791..1181.181 rows=2375127 loops=1)
# 11                                                                                                                           Hash Cond: (inp.booktitle = inproceedings.booktitle)
# 12                                                                                                                                          Buffers: shared hit=31928 read=133286
# 13                                              ->  Seq Scan on inproceedings inp  (cost=0.00..117162.05 rows=3455505 width=13) (actual time=0.009..354.760 rows=3455505 loops=1)
# 14                                                                                                                                           Buffers: shared hit=16012 read=66595
# 15                                                                       ->  Hash  (cost=103928.10..103928.10 rows=6022 width=8) (actual time=272.773..272.817 rows=2901 loops=1)
# 16                                                                                                                                 Buckets: 8192  Batches: 1  Memory Usage: 183kB
# 17                                                                                                                                           Buffers: shared hit=15916 read=66691
# 18                                                                     ->  Unique  (cost=103867.88..103928.10 rows=6022 width=8) (actual time=271.973..272.536 rows=2901 loops=1)
# 19                                                                                                                                           Buffers: shared hit=15916 read=66691
# 20                                                                      ->  Sort  (cost=103867.88..103897.99 rows=12044 width=8) (actual time=271.972..272.135 rows=4314 loops=1)
# 21                                                                                                                                              Sort Key: inproceedings.booktitle
# 22                                                                                                                                          Sort Method: quicksort  Memory: 283kB
# 23                                                                                                                                           Buffers: shared hit=15916 read=66691
# 24                                                                    ->  Gather  (cost=101786.92..103051.54 rows=12044 width=8) (actual time=263.141..263.631 rows=4314 loops=1)
# 25                                                                                                                                                             Workers Planned: 2
# 26                                                                                                                                                            Workers Launched: 2
# 27                                                                                                                                           Buffers: shared hit=15916 read=66691
# 28                                                              ->  HashAggregate  (cost=100786.92..100847.14 rows=6022 width=8) (actual time=210.237..210.382 rows=1438 loops=3)
# 29                                                                                                                                             Group Key: inproceedings.booktitle
# 30                                                                                                                                                Batches: 1  Memory Usage: 337kB
# 31                                                                                                                                           Buffers: shared hit=15916 read=66691
# 32                                                                                                                                     Worker 0:  Batches: 1  Memory Usage: 337kB
# 33                                                                                                                                     Worker 1:  Batches: 1  Memory Usage: 273kB
# 34                                              ->  Parallel Seq Scan on inproceedings  (cost=0.00..100604.42 rows=72998 width=8) (actual time=0.305..201.210 rows=58681 loops=3)
# 35                                                                                                                                                  Filter: (year = '2018'::text)
# 36                                                                                                                                                Rows Removed by Filter: 1093154
# 37                                                                                                                                           Buffers: shared hit=15916 read=66691
# 38                                                                                                                                                        Planning Time: 0.159 ms
# 39                                                                                                                                                    Execution Time: 1527.914 ms
# EXPLAIN results
#                                                                                                                                                                                           QUERY PLAN
# 0                                                                                              Unique  (cost=416268.58..508132.91 rows=200 width=8) (actual time=944.256..956.138 rows=1456 loops=1)
# 1                                                                                                                                                  Buffers: shared hit=135348 read=125840 written=12
# 2                                                                ->  Subquery Scan on paper_counts  (cost=416268.58..507844.95 rows=115183 width=8) (actual time=944.255..955.860 rows=2691 loops=1)
# 3                                                                                                                                                  Buffers: shared hit=135348 read=125840 written=12
# 4                                                                     ->  Finalize GroupAggregate  (cost=416268.58..506693.12 rows=115183 width=48) (actual time=944.254..955.725 rows=2691 loops=1)
# 5                                                                                                                                                 Group Key: inp.booktitle, (substr(inp.year, 3, 1))
# 6                                                                                                                                                                          Filter: (count(*) >= 200)
# 7                                                                                                                                                                       Rows Removed by Filter: 3890
# 8                                                                                                                                                  Buffers: shared hit=135348 read=125840 written=12
# 9                                                                               ->  Gather Merge  (cost=416268.58..496902.54 rows=691100 width=48) (actual time=944.243..953.757 rows=11304 loops=1)
# 10                                                                                                                                                                                Workers Planned: 2
# 11                                                                                                                                                                               Workers Launched: 2
# 12                                                                                                                                                 Buffers: shared hit=135348 read=125840 written=12
# 13                                                                                       ->  Sort  (cost=415268.55..416132.43 rows=345550 width=48) (actual time=924.705..924.921 rows=3768 loops=3)
# 14                                                                                                                                                 Sort Key: inp.booktitle, (substr(inp.year, 3, 1))
# 15                                                                                                                                                             Sort Method: quicksort  Memory: 270kB
# 16                                                                                                                                                 Buffers: shared hit=135348 read=125840 written=12
# 17                                                                                                                                                  Worker 0:  Sort Method: quicksort  Memory: 263kB
# 18                                                                                                                                                  Worker 1:  Sort Method: quicksort  Memory: 263kB
# 19                                                                      ->  Partial HashAggregate  (cost=346031.33..372847.48 rows=345550 width=48) (actual time=915.832..916.474 rows=3768 loops=3)
# 20                                                                                                                                                  Group Key: inp.booktitle, substr(inp.year, 3, 1)
# 21                                                                                                                                           Planned Partitions: 8  Batches: 1  Memory Usage: 2065kB
# 22                                                                                                                                                 Buffers: shared hit=135333 read=125839 written=12
# 23                                                                                                                                                       Worker 0:  Batches: 1  Memory Usage: 1809kB
# 24                                                                                                                                                       Worker 1:  Batches: 1  Memory Usage: 1809kB
# 25                                                                               ->  Hash Join  (cost=112063.33..216449.87 rows=1439794 width=40) (actual time=419.530..790.304 rows=791709 loops=3)
# 26                                                                                                                                              Hash Cond: (inp.booktitle = inproceedings.booktitle)
# 27                                                                                                                                                 Buffers: shared hit=135333 read=125839 written=12
# 28                                                         ->  Parallel Seq Scan on inproceedings inp  (cost=0.00..97004.94 rows=1439794 width=13) (actual time=0.025..168.711 rows=1151835 loops=3)
# 29                                                                                                                                                              Buffers: shared hit=16287 read=66320
# 30                                                                                          ->  Hash  (cost=111988.05..111988.05 rows=6022 width=8) (actual time=419.461..419.462 rows=2901 loops=3)
# 31                                                                                                                                                    Buckets: 8192  Batches: 1  Memory Usage: 183kB
# 32                                                                                                                                                  Buffers: shared hit=119042 read=59517 written=12
# 33                                                                                 ->  HashAggregate  (cost=111927.83..111988.05 rows=6022 width=8) (actual time=418.840..419.125 rows=2901 loops=3)
# 34                                                                                                                                                                Group Key: inproceedings.booktitle
# 35                                                                                                                                                                   Batches: 1  Memory Usage: 337kB
# 36                                                                                                                                                  Buffers: shared hit=119042 read=59517 written=12
# 37                                                                                                                                                        Worker 0:  Batches: 1  Memory Usage: 337kB
# 38                                                                                                                                                        Worker 1:  Batches: 1  Memory Usage: 337kB
# 39                                                            ->  Bitmap Heap Scan on inproceedings  (cost=1954.18..111489.85 rows=175194 width=8) (actual time=16.658..375.129 rows=176043 loops=3)
# 40                                                                                                                                                               Recheck Cond: (year = '2018'::text)
# 41                                                                                                                                                                          Heap Blocks: exact=59368
# 42                                                                                                                                                  Buffers: shared hit=119042 read=59517 written=12
# 43                                                          ->  Bitmap Index Scan on idx_year_inproceedings  (cost=0.00..1910.38 rows=175194 width=0) (actual time=9.749..9.749 rows=176043 loops=3)
# 44                                                                                                                                                                 Index Cond: (year = '2018'::text)
# 45                                                                                                                                                                  Buffers: shared hit=304 read=151
# 46                                                                                                                                                                                         Planning:
# 47                                                                                                                                                                     Buffers: shared hit=30 read=4
# 48                                                                                                                                                                           Planning Time: 1.032 ms
# 49                                                                                                                                                                        Execution Time: 957.015 ms
