# %% [markdown]
# #### SQL Tuning Exploration
# In this notebook, we explore the effect that table indexes can have on query performance. Here, a series of five questions have been presented based on the ingested DBLP dataset. For each question, a link to the query logic is provided, which includes the commands used for the creation of table indexes. Results are displayed for query performance both before and after building indexes for comparison and commentary.

# %%
# Packages
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import text
from sqlalchemy.orm import sessionmaker
import os
from dotenv import load_dotenv
import logging
import re

# %%
# Constants
load_dotenv("../src/.env")
DB_USER = os.getenv("DB_USER")
DB_NAME = "dblp"
DB_PASSWORD = os.getenv("DB_PASSWORD")
HOST = os.getenv("HOST")
PORT = os.getenv("PORT")
CONNECT_STRING = f"postgresql://{DB_USER}:{DB_PASSWORD}@{HOST}:{PORT}/{DB_NAME}"
SQL_CODE = "../src/sql_tuning_testing.sql"

# Settings
pd.set_option('display.max_colwidth', None)

# Engine
engine = create_engine(CONNECT_STRING)
Session = sessionmaker(engine)

# %%
# Parse query into a dictionary of dictionaries with keys (Question, Query, Indexes, Cleanup)
with open(SQL_CODE) as f:
    code = [i.split("--")[1:] for i in f.read().split("-- P")[1:]]

parsed_query = {f"P{k+1}":v for k,v in 
                enumerate([{re.sub(r"^/\*(\w+):[\S\s]*", r"\1",i):re.sub(r"\*/","",re.sub(r"^.*:\*/\n|^.*: ", "",i)) for i in j} for j in code])}

# %%
def indexing_experiment(question_num):
    """Helper function to iterate through parsed SQL code to run each query, evaluate performance with/without indices, and
    cleanup."""
    context = parsed_query[question_num]
    # Show Question
    print(context['Question'])

    # Show query result
    print("Query Result (First 5 rows)")
    display(pd.read_sql(context['Query'], engine).head())

    # Explain results before indexing
    print('EXPLAIN results - before indexing')
    before = pd.read_sql("EXPLAIN (ANALYZE,BUFFERS) " + context['Query'], engine)
    display(before)

    # Run indexing
    with Session() as session:
        session.execute(text(context['Indexing']))
        session.commit()

    # Re-run Explain
    print('EXPLAIN results - after indexing')
    after = pd.read_sql("EXPLAIN (ANALYZE,BUFFERS) " + context['Query'], engine)
    display(after)

    # Cleanup indexes
    with Session() as session:
        session.execute(text(context['Cleanup']))
        session.commit()

# %% [markdown]
# ##### Question 1:
#
# <a href="https://github.com/andrewcockerill/springboard_06_sql_tuning/blob/main/src/sql_tuning_testing.sql#L1">SQL Code</a>
#
# We can see that by adding indices on <tt>year</tt> (function index using <tt>substr(year,3,1)</tt> to encode the decade) and <tt>booktitle</tt> to table, the cost decreases from 609916 to 416268, with a run time reduction of from ~1500 ms to ~900 ms.

# %%
indexing_experiment("P1")
# Out:
# Write a SQL Query to find all the conferences held in 2018 that have published at least 200 papers in a single decade.
#
#
# Query Result (First 5 rows)
#   booktitle
# 0    COLINS
# 1   ICL (2)
# 2   CBI (1)
# 3     ICSOC
# 4        FG
# EXPLAIN results - before indexing
#                                                                                                                                                                        QUERY PLAN
# 0                                                                  HashAggregate  (cost=609916.11..609918.11 rows=200 width=8) (actual time=1556.229..1556.344 rows=1456 loops=1)
# 1                                                                                                                                                        Group Key: inp.booktitle
# 2                                                                                                                                                 Batches: 1  Memory Usage: 145kB
# 3                                                                                                                                            Buffers: shared hit=4763 read=160451
# 4                                                          ->  HashAggregate  (cost=549876.72..608476.32 rows=115183 width=48) (actual time=1554.915..1555.835 rows=2691 loops=1)
# 5                                                                                                                                Group Key: inp.booktitle, substr(inp.year, 3, 1)
# 6                                                                                                                                                       Filter: (count(*) >= 200)
# 7                                                                                                                         Planned Partitions: 8  Batches: 1  Memory Usage: 2065kB
# 8                                                                                                                                                    Rows Removed by Filter: 3890
# 9                                                                                                                                            Buffers: shared hit=4763 read=160451
# 10                                                          ->  Hash Join  (cost=104003.38..238881.27 rows=3455505 width=40) (actual time=252.929..1197.610 rows=2375127 loops=1)
# 11                                                                                                                           Hash Cond: (inp.booktitle = inproceedings.booktitle)
# 12                                                                                                                                           Buffers: shared hit=4763 read=160451
# 13                                              ->  Seq Scan on inproceedings inp  (cost=0.00..117162.05 rows=3455505 width=13) (actual time=0.029..388.065 rows=3455505 loops=1)
# 14                                                                                                                                            Buffers: shared hit=2429 read=80178
# 15                                                                       ->  Hash  (cost=103928.10..103928.10 rows=6022 width=8) (actual time=252.881..252.918 rows=2901 loops=1)
# 16                                                                                                                                 Buckets: 8192  Batches: 1  Memory Usage: 183kB
# 17                                                                                                                                            Buffers: shared hit=2334 read=80273
# 18                                                                     ->  Unique  (cost=103867.88..103928.10 rows=6022 width=8) (actual time=252.045..252.646 rows=2901 loops=1)
# 19                                                                                                                                            Buffers: shared hit=2334 read=80273
# 20                                                                      ->  Sort  (cost=103867.88..103897.99 rows=12044 width=8) (actual time=252.044..252.208 rows=4621 loops=1)
# 21                                                                                                                                              Sort Key: inproceedings.booktitle
# 22                                                                                                                                          Sort Method: quicksort  Memory: 290kB
# 23                                                                                                                                            Buffers: shared hit=2334 read=80273
# 24                                                                    ->  Gather  (cost=101786.92..103051.54 rows=12044 width=8) (actual time=242.199..242.708 rows=4621 loops=1)
# 25                                                                                                                                                             Workers Planned: 2
# 26                                                                                                                                                            Workers Launched: 2
# 27                                                                                                                                            Buffers: shared hit=2334 read=80273
# 28                                                              ->  HashAggregate  (cost=100786.92..100847.14 rows=6022 width=8) (actual time=226.613..226.768 rows=1540 loops=3)
# 29                                                                                                                                             Group Key: inproceedings.booktitle
# 30                                                                                                                                                Batches: 1  Memory Usage: 337kB
# 31                                                                                                                                            Buffers: shared hit=2334 read=80273
# 32                                                                                                                                     Worker 0:  Batches: 1  Memory Usage: 337kB
# 33                                                                                                                                     Worker 1:  Batches: 1  Memory Usage: 337kB
# 34                                              ->  Parallel Seq Scan on inproceedings  (cost=0.00..100604.42 rows=72998 width=8) (actual time=0.167..217.117 rows=58681 loops=3)
# 35                                                                                                                                                  Filter: (year = '2018'::text)
# 36                                                                                                                                                Rows Removed by Filter: 1093154
# 37                                                                                                                                            Buffers: shared hit=2334 read=80273
# 38                                                                                                                                                        Planning Time: 0.165 ms
# 39                                                                                                                                                    Execution Time: 1556.827 ms
# EXPLAIN results - after indexing
#                                                                                                                                                                                           QUERY PLAN
# 0                                                                                              Unique  (cost=416268.58..508132.91 rows=200 width=8) (actual time=966.182..977.967 rows=1456 loops=1)
# 1                                                                                                                                                   Buffers: shared hit=79371 read=181817 written=10
# 2                                                                ->  Subquery Scan on paper_counts  (cost=416268.58..507844.95 rows=115183 width=8) (actual time=966.182..977.685 rows=2691 loops=1)
# 3                                                                                                                                                   Buffers: shared hit=79371 read=181817 written=10
# 4                                                                     ->  Finalize GroupAggregate  (cost=416268.58..506693.12 rows=115183 width=48) (actual time=966.181..977.543 rows=2691 loops=1)
# 5                                                                                                                                                 Group Key: inp.booktitle, (substr(inp.year, 3, 1))
# 6                                                                                                                                                                          Filter: (count(*) >= 200)
# 7                                                                                                                                                                       Rows Removed by Filter: 3890
# 8                                                                                                                                                   Buffers: shared hit=79371 read=181817 written=10
# 9                                                                               ->  Gather Merge  (cost=416268.58..496902.54 rows=691100 width=48) (actual time=966.170..975.595 rows=11201 loops=1)
# 10                                                                                                                                                                                Workers Planned: 2
# 11                                                                                                                                                                               Workers Launched: 2
# 12                                                                                                                                                  Buffers: shared hit=79371 read=181817 written=10
# 13                                                                                       ->  Sort  (cost=415268.55..416132.43 rows=345550 width=48) (actual time=914.609..914.795 rows=3734 loops=3)
# 14                                                                                                                                                 Sort Key: inp.booktitle, (substr(inp.year, 3, 1))
# 15                                                                                                                                                             Sort Method: quicksort  Memory: 271kB
# 16                                                                                                                                                  Buffers: shared hit=79371 read=181817 written=10
# 17                                                                                                                                                  Worker 0:  Sort Method: quicksort  Memory: 274kB
# 18                                                                                                                                                  Worker 1:  Sort Method: quicksort  Memory: 245kB
# 19                                                                      ->  Partial HashAggregate  (cost=346031.33..372847.48 rows=345550 width=48) (actual time=905.926..906.559 rows=3734 loops=3)
# 20                                                                                                                                                  Group Key: inp.booktitle, substr(inp.year, 3, 1)
# 21                                                                                                                                           Planned Partitions: 8  Batches: 1  Memory Usage: 2065kB
# 22                                                                                                                                                  Buffers: shared hit=79355 read=181817 written=10
# 23                                                                                                                                                       Worker 0:  Batches: 1  Memory Usage: 2065kB
# 24                                                                                                                                                       Worker 1:  Batches: 1  Memory Usage: 1809kB
# 25                                                                               ->  Hash Join  (cost=112063.33..216449.87 rows=1439794 width=40) (actual time=411.208..780.265 rows=791709 loops=3)
# 26                                                                                                                                              Hash Cond: (inp.booktitle = inproceedings.booktitle)
# 27                                                                                                                                                  Buffers: shared hit=79355 read=181817 written=10
# 28                                                         ->  Parallel Seq Scan on inproceedings inp  (cost=0.00..97004.94 rows=1439794 width=13) (actual time=0.038..167.696 rows=1151835 loops=3)
# 29                                                                                                                                                              Buffers: shared hit=16286 read=66321
# 30                                                                                          ->  Hash  (cost=111988.05..111988.05 rows=6022 width=8) (actual time=411.135..411.136 rows=2901 loops=3)
# 31                                                                                                                                                    Buckets: 8192  Batches: 1  Memory Usage: 183kB
# 32                                                                                                                                                  Buffers: shared hit=63063 read=115496 written=10
# 33                                                                                 ->  HashAggregate  (cost=111927.83..111988.05 rows=6022 width=8) (actual time=410.500..410.794 rows=2901 loops=3)
# 34                                                                                                                                                                Group Key: inproceedings.booktitle
# 35                                                                                                                                                                   Batches: 1  Memory Usage: 337kB
# 36                                                                                                                                                  Buffers: shared hit=63063 read=115496 written=10
# 37                                                                                                                                                        Worker 0:  Batches: 1  Memory Usage: 337kB
# 38                                                                                                                                                        Worker 1:  Batches: 1  Memory Usage: 337kB
# 39                                                            ->  Bitmap Heap Scan on inproceedings  (cost=1954.18..111489.85 rows=175194 width=8) (actual time=16.553..372.836 rows=176043 loops=3)
# 40                                                                                                                                                               Recheck Cond: (year = '2018'::text)
# 41                                                                                                                                                                          Heap Blocks: exact=59368
# 42                                                                                                                                                  Buffers: shared hit=63063 read=115496 written=10
# 43                                                          ->  Bitmap Index Scan on idx_year_inproceedings  (cost=0.00..1910.38 rows=175194 width=0) (actual time=9.849..9.849 rows=176043 loops=3)
# 44                                                                                                                                                                 Index Cond: (year = '2018'::text)
# 45                                                                                                                                                                  Buffers: shared hit=152 read=303
# 46                                                                                                                                                                                         Planning:
# 47                                                                                                                                                                     Buffers: shared hit=35 read=2
# 48                                                                                                                                                                           Planning Time: 0.869 ms
# 49                                                                                                                                                                        Execution Time: 978.993 ms

# %% [markdown]
# ##### Question 2:
#
# <a href="https://github.com/andrewcockerill/springboard_06_sql_tuning/blob/main/src/sql_tuning_testing.sql#L42">SQL Code</a>
#
# Here, indices were made for <tt>booktitle</tt> (conference) and <tt>journal</tt> to assist when doing filters on these columns. This resulted in a performance gain by reducing cost and execution times (1060 ms to 7 ms).

# %%
indexing_experiment('P2')
# Out:
# Write a SQL Query to find all the authors who published at least 10 PVLDB papers and at least 10 SIGMOD papers.
#
#
# Query Result (First 5 rows)
#                          author
# 0  Andrew Eisenberg::Jim Melton
# 1           Michael Stonebraker
# 2                   Karl Aberer
# 3           Michael J. Franklin
# 4                    Arie Segev
# EXPLAIN results - before indexing
#                                                                                                                                                                                                                   QUERY PLAN
# 0                                                                                                         HashSetOp Intersect  (cost=217794.08..435616.22 rows=67 width=36) (actual time=1059.692..1065.038 rows=16 loops=1)
# 1                                                                                                                                                                                      Buffers: shared hit=32466 read=309686
# 2                                                                                                                  ->  Append  (cost=217794.08..435615.88 rows=134 width=36) (actual time=532.087..1065.023 rows=38 loops=1)
# 3                                                                                                                                                                                      Buffers: shared hit=32466 read=309686
# 4                                                                                             ->  Subquery Scan on "*SELECT* 1"  (cost=217794.08..217922.18 rows=67 width=57) (actual time=532.086..538.274 rows=18 loops=1)
# ..                                                                                                                                                                                                                       ...
# 61                                                    Filter: (journal = ANY ('{"ACM SIGMOD Anthology","ACM SIGMOD Digit. Rev.","ACM SIGMOD Digit. Symp. Collect.","FDT Bull. ACM SIGFIDET SIGMOD","SIGMOD Rec."}'::text[]))
# 62                                                                                                                                                                                           Rows Removed by Filter: 1733055
# 63                                                                                                                                                                                        Buffers: shared hit=192 read=88203
# 64                                                                                                                                                                                                   Planning Time: 0.482 ms
# 65                                                                                                                                                                                               Execution Time: 1065.121 ms
#
# [66 rows x 1 columns]
# EXPLAIN results - after indexing
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        QUERY PLAN
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     HashSetOp Intersect  (cost=62576.55..113067.38 rows=67 width=36) (actual time=7.599..7.603 rows=16 loops=1)
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Buffers: shared hit=286 read=347
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ->  Append  (cost=62576.55..113067.04 rows=134 width=36) (actual time=4.362..7.593 rows=38 loops=1)
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Buffers: shared hit=286 read=347
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ->  Subquery Scan on "*SELECT* 1"  (cost=62576.55..62579.72 rows=67 width=57) (actual time=4.362..4.976 rows=18 loops=1)
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Buffers: shared hit=73 read=301
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ->  HashAggregate  (cost=62576.55..62579.05 rows=67 width=53) (actual time=4.362..4.974 rows=18 loops=1)
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Group Key: inproceedings.author
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Filter: (count(*) >= 10)
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Batches: 1  Memory Usage: 1441kB
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Rows Removed by Filter: 6413
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Buffers: shared hit=73 read=301
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ->  Append  (cost=288.97..62456.95 rows=23920 width=53) (actual time=0.423..2.492 rows=7404 loops=1)
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Buffers: shared hit=73 read=301
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ->  Bitmap Heap Scan on inproceedings  (cost=288.97..44585.57 rows=18383 width=53) (actual time=0.423..1.530 rows=5347 loops=1)
# 15                                      Recheck Cond: (booktitle = ANY ('{"1999 ACM SIGMOD Workshop on Research Issues in Data Mining and Knowledge Discovery","ACM SIGMOD Workshop on Research Issues in Data Mining and Knowledge Discovery",aiDM@SIGMOD,BeyondMR@SIGMOD,BiDEDE@SIGMOD,DanaC@SIGMOD,DataEd@SIGMOD,DBTest@SIGMOD,DEBT@SIGMOD,DEC@SIGMOD,DEEM@SIGMOD,DSMM@SIGMOD,DyNetMM@SIGMOD,ExploreDB@SIGMOD/PODS,GeoRich@SIGMOD,GRADES-NDA@SIGMOD,GRADES/NDA@SIGMOD/PODS,GRADES@SIGMOD/PODS,HILDA@SIGMOD,NDA@SIGMOD,SBD@SIGMOD,"SIGMOD Conference","SIGMOD Conference Companion","SIGMOD PhD Symposium","SIGMOD Workshop, Vol. 1","SIGMOD Workshop, Vol. 2","SIGMOD/PODS Ph.D. Symposium","SIGMOD/PODS PhD Symposium","SIGSMALL/SIGMOD Symposium",SiMoD@SIGMOD,SWEET@SIGMOD,"SWIM@SIGMOD Conference",VDBS@SIGMOD}'::text[]))
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Filter: (author IS NOT NULL)
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Rows Removed by Filter: 4
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Heap Blocks: exact=174
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Buffers: shared hit=65 read=211
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ->  Bitmap Index Scan on idx_booktitle_inproceedings  (cost=0.00..284.30 rows=18419 width=0) (actual time=0.399..0.399 rows=5351 loops=1)
# 21                                        Index Cond: (booktitle = ANY ('{"1999 ACM SIGMOD Workshop on Research Issues in Data Mining and Knowledge Discovery","ACM SIGMOD Workshop on Research Issues in Data Mining and Knowledge Discovery",aiDM@SIGMOD,BeyondMR@SIGMOD,BiDEDE@SIGMOD,DanaC@SIGMOD,DataEd@SIGMOD,DBTest@SIGMOD,DEBT@SIGMOD,DEC@SIGMOD,DEEM@SIGMOD,DSMM@SIGMOD,DyNetMM@SIGMOD,ExploreDB@SIGMOD/PODS,GeoRich@SIGMOD,GRADES-NDA@SIGMOD,GRADES/NDA@SIGMOD/PODS,GRADES@SIGMOD/PODS,HILDA@SIGMOD,NDA@SIGMOD,SBD@SIGMOD,"SIGMOD Conference","SIGMOD Conference Companion","SIGMOD PhD Symposium","SIGMOD Workshop, Vol. 1","SIGMOD Workshop, Vol. 2","SIGMOD/PODS Ph.D. Symposium","SIGMOD/PODS PhD Symposium","SIGSMALL/SIGMOD Symposium",SiMoD@SIGMOD,SWEET@SIGMOD,"SWIM@SIGMOD Conference",VDBS@SIGMOD}'::text[]))
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Buffers: shared hit=64 read=38
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ->  Bitmap Heap Scan on article  (cost=65.31..17751.79 rows=5537 width=53) (actual time=0.112..0.632 rows=2057 loops=1)
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Recheck Cond: (journal = ANY ('{"ACM SIGMOD Anthology","ACM SIGMOD Digit. Rev.","ACM SIGMOD Digit. Symp. Collect.","FDT Bull. ACM SIGFIDET SIGMOD","SIGMOD Rec."}'::text[]))
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Filter: (author IS NOT NULL)
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Rows Removed by Filter: 133
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Heap Blocks: exact=81
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Buffers: shared hit=8 read=90
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ->  Bitmap Index Scan on idx_journal_article  (cost=0.00..63.92 rows=5570 width=0) (actual time=0.093..0.093 rows=2190 loops=1)
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Index Cond: (journal = ANY ('{"ACM SIGMOD Anthology","ACM SIGMOD Digit. Rev.","ACM SIGMOD Digit. Symp. Collect.","FDT Bull. ACM SIGFIDET SIGMOD","SIGMOD Rec."}'::text[]))
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Buffers: shared hit=8 read=9
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ->  Subquery Scan on "*SELECT* 2"  (cost=50483.48..50486.65 rows=67 width=57) (actual time=2.395..2.615 rows=20 loops=1)
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Buffers: shared hit=213 read=46
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ->  HashAggregate  (cost=50483.48..50485.98 rows=67 width=53) (actual time=2.395..2.613 rows=20 loops=1)
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Group Key: inproceedings_1.author
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Filter: (count(*) >= 10)
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Batches: 1  Memory Usage: 993kB
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Rows Removed by Filter: 4231
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Buffers: shared hit=213 read=46
# 40                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ->  Append  (cost=216.12..50396.21 rows=17454 width=53) (actual time=0.321..1.207 rows=5275 loops=1)
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Buffers: shared hit=213 read=46
# 42                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ->  Bitmap Heap Scan on inproceedings inproceedings_1  (cost=216.12..32557.15 rows=11884 width=53) (actual time=0.321..0.696 rows=3085 loops=1)
# 43                                                                                                                                                                                                                                                                                                                                                                                              Recheck Cond: (booktitle = ANY ('{ADMS/IMDM@VLDB,ADMS@VLDB,AIDB@VLDB,BD3@VLDB,BiDu-Posters@VLDB,BiDU@VLDB,Big-O(Q)/DMAH@VLDB,BPOE@ASPLOS/VLDB,CDMS@VLDB,CSW@VLDB,Data4U@VLDB,DBRank@VLDB,DEco@VLDB,DI2KG@VLDB,DMAH@VLDB,IMDM@VLDB,"IMDM@VLDB (Revised Selected Papers)",LADaS@VLDB,MATES@VLDB,PhD@VLDB,Poly/DMAH@VLDB,SEA-Data@VLDB,SFDI/LSGDA@VLDB,SSW@VLDB,VLDB,"VLDB PhD Workshop","VLDB Surveys","VLDB Workshops"}'::text[]))
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Heap Blocks: exact=75
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Buffers: shared hit=115 read=46
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ->  Bitmap Index Scan on idx_booktitle_inproceedings  (cost=0.00..213.08 rows=11884 width=0) (actual time=0.288..0.289 rows=3085 loops=1)
# 47                                                                                                                                                                                                                                                                                                                                                                                                Index Cond: (booktitle = ANY ('{ADMS/IMDM@VLDB,ADMS@VLDB,AIDB@VLDB,BD3@VLDB,BiDu-Posters@VLDB,BiDU@VLDB,Big-O(Q)/DMAH@VLDB,BPOE@ASPLOS/VLDB,CDMS@VLDB,CSW@VLDB,Data4U@VLDB,DBRank@VLDB,DEco@VLDB,DI2KG@VLDB,DMAH@VLDB,IMDM@VLDB,"IMDM@VLDB (Revised Selected Papers)",LADaS@VLDB,MATES@VLDB,PhD@VLDB,Poly/DMAH@VLDB,SEA-Data@VLDB,SFDI/LSGDA@VLDB,SSW@VLDB,VLDB,"VLDB PhD Workshop","VLDB Surveys","VLDB Workshops"}'::text[]))
# 48                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Buffers: shared hit=64 read=22
# 49                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ->  Bitmap Heap Scan on article article_1  (cost=65.32..17751.79 rows=5570 width=53) (actual time=0.060..0.259 rows=2190 loops=1)
# 50                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Recheck Cond: (journal = ANY ('{"ACM SIGMOD Anthology","ACM SIGMOD Digit. Rev.","ACM SIGMOD Digit. Symp. Collect.","FDT Bull. ACM SIGFIDET SIGMOD","SIGMOD Rec."}'::text[]))
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Heap Blocks: exact=81
# 52                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Buffers: shared hit=98
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ->  Bitmap Index Scan on idx_journal_article  (cost=0.00..63.92 rows=5570 width=0) (actual time=0.054..0.054 rows=2190 loops=1)
# 54                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Index Cond: (journal = ANY ('{"ACM SIGMOD Anthology","ACM SIGMOD Digit. Rev.","ACM SIGMOD Digit. Symp. Collect.","FDT Bull. ACM SIGFIDET SIGMOD","SIGMOD Rec."}'::text[]))
# 55                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Buffers: shared hit=17
# 56                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Planning:
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Buffers: shared hit=32 read=2
# 58                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Planning Time: 1.344 ms
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Execution Time: 7.855 ms

# %% [markdown]
# ##### Question 3:
#
# <a href="https://github.com/andrewcockerill/springboard_06_sql_tuning/blob/main/src/sql_tuning_testing.sql#L134">SQL Code</a>
#
# In this case a functional index was made on <tt>substr(year,3,1)</tt> as done previously, though this only resulted in a modest performance gain from 21 ms to 15 ms.

# %%
indexing_experiment('P3')
# Out:
# Write a SQL Query to find the total number of conference publications for each decade, starting from 1970 and ending in 2019.
#
#
# Query Result (First 5 rows)
#   decade  count
# 0      0  13575
# 1      9   4450
# 2      7    355
# 3      1  26598
# 4      8   1202
# EXPLAIN results - before indexing
#                                                                                                               QUERY PLAN
# 0                    HashAggregate  (cost=3056.72..3057.61 rows=71 width=40) (actual time=20.294..20.295 rows=5 loops=1)
# 1                                                                              Group Key: substr(proceedings.year, 3, 1)
# 2                                                                                         Batches: 1  Memory Usage: 24kB
# 3                                                                                               Buffers: shared hit=1956
# 4    ->  Seq Scan on proceedings  (cost=0.00..3049.46 rows=1453 width=32) (actual time=0.009..15.531 rows=46180 loops=1)
# 5                                                             Filter: (substr(year, 3, 1) = ANY ('{7,8,9,0,1}'::text[]))
# 6                                                                                          Rows Removed by Filter: 11944
# 7                                                                                               Buffers: shared hit=1956
# 8                                                                                                Planning Time: 0.081 ms
# 9                                                                                              Execution Time: 20.309 ms
# EXPLAIN results - after indexing
#                                                                                                                                      QUERY PLAN
# 0                                           HashAggregate  (cost=1969.90..1970.79 rows=71 width=40) (actual time=14.446..14.447 rows=5 loops=1)
# 1                                                                                                     Group Key: substr(proceedings.year, 3, 1)
# 2                                                                                                                Batches: 1  Memory Usage: 24kB
# 3                                                                                                              Buffers: shared hit=1963 read=41
# 4                   ->  Bitmap Heap Scan on proceedings  (cost=32.73..1962.63 rows=1453 width=32) (actual time=1.085..9.696 rows=46180 loops=1)
# 5                                                                              Recheck Cond: (substr(year, 3, 1) = ANY ('{7,8,9,0,1}'::text[]))
# 6                                                                                                                       Heap Blocks: exact=1956
# 7                                                                                                              Buffers: shared hit=1963 read=41
# 8           ->  Bitmap Index Scan on idx_decade_proceedings  (cost=0.00..32.36 rows=1453 width=0) (actual time=0.928..0.928 rows=46180 loops=1)
# 9                                                                                Index Cond: (substr(year, 3, 1) = ANY ('{7,8,9,0,1}'::text[]))
# 10                                                                                                                Buffers: shared hit=7 read=41
# 11                                                                                                                                    Planning:
# 12                                                                                                                Buffers: shared hit=18 read=1
# 13                                                                                                                      Planning Time: 0.543 ms
# 14                                                                                                                    Execution Time: 14.503 ms

# %% [markdown]
# ##### Question 4:
#
# <a href="https://github.com/andrewcockerill/springboard_06_sql_tuning/blob/main/src/sql_tuning_testing.sql#L159">SQL Code</a>
#
# For this query, a full text approach was used in which a GIN index was created on the <tt>TO_TSVECTOR</tt> for the <tt>title</tt> columns in <tt>article</tt> and <tt>inproceedings</tt>. The rationale to use TS_QUERY in this case was to isolate just instances of the <tt>"data"</tt> token by itself. This resulted in a drop in cost and run time of the query.

# %%
indexing_experiment('P4')
# Out:
# Write a SQL Query to find the top 10 authors publishing in journals and conferences whose titles contain the word data.
#
#
# Query Result (First 5 rows)
#                             author  papers
# 0                Alfredo Cuzzocrea      71
# 1                       Complexity      23
# 2            Bhavani Thuraisingham      23
# 3  Charu C. Aggarwal::Philip S. Yu      23
# 4                Charu C. Aggarwal      22
# EXPLAIN results - before indexing
#                                                                                                                                                                        QUERY PLAN
# 0                                                                        Limit  (cost=1651745.98..1651746.00 rows=10 width=61) (actual time=20681.233..20684.525 rows=10 loops=1)
# 1                                                                                                              Buffers: shared hit=14626 read=157104, temp read=2794 written=2800
# 2                                                                    ->  Sort  (cost=1651745.98..1651746.48 rows=200 width=61) (actual time=20681.232..20684.524 rows=10 loops=1)
# 3                                                                                                                                                       Sort Key: (count(*)) DESC
# 4                                                                                                                                       Sort Method: top-N heapsort  Memory: 25kB
# 5                                                                                                              Buffers: shared hit=14626 read=157104, temp read=2794 written=2800
# 6                                             ->  Finalize GroupAggregate  (cost=1651582.16..1651741.66 rows=200 width=61) (actual time=20240.596..20653.543 rows=316323 loops=1)
# 7                                                                                                                                                       Group Key: article.author
# 8                                                                                                              Buffers: shared hit=14626 read=157104, temp read=2794 written=2800
# 9                                                        ->  Gather Merge  (cost=1651582.16..1651737.66 rows=400 width=61) (actual time=20240.591..20580.750 rows=341716 loops=1)
# 10                                                                                                                                                             Workers Planned: 2
# 11                                                                                                                                                            Workers Launched: 2
# 12                                                                                                             Buffers: shared hit=14622 read=157104, temp read=2794 written=2800
# 13                                             ->  Partial GroupAggregate  (cost=1650582.14..1650691.46 rows=200 width=61) (actual time=20207.021..20316.354 rows=113905 loops=3)
# 14                                                                                                                                                      Group Key: article.author
# 15                                                                                                             Buffers: shared hit=14576 read=157104, temp read=2794 written=2800
# 16                                                             ->  Sort  (cost=1650582.14..1650617.91 rows=14310 width=53) (actual time=20207.015..20284.395 rows=121246 loops=3)
# 17                                                                                                                                                       Sort Key: article.author
# 18                                                                                                                                      Sort Method: external merge  Disk: 7720kB
# 19                                                                                                             Buffers: shared hit=14576 read=157104, temp read=2794 written=2800
# 20                                                                                                                           Worker 0:  Sort Method: external merge  Disk: 7032kB
# 21                                                                                                                           Worker 1:  Sort Method: external merge  Disk: 7600kB
# 22                                                            ->  Parallel Append  (cost=0.00..1649594.41 rows=14310 width=53) (actual time=1.277..19725.803 rows=121246 loops=3)
# 23                                                                                                                                          Buffers: shared hit=14236 read=157104
# 24                                                  ->  Parallel Seq Scan on article  (cost=0.00..829021.56 rows=7139 width=53) (actual time=1.068..10150.531 rows=58778 loops=3)
# 25                                              Filter: ((author IS NOT NULL) AND (author IS NOT NULL) AND (to_tsvector('simple'::regconfig, title) @@ to_tsquery('data'::text)))
# 26                                                                                                                                                Rows Removed by Filter: 1097322
# 27                                                                                                                                             Buffers: shared hit=508 read=88056
# 28                                            ->  Parallel Seq Scan on inproceedings  (cost=0.00..820501.30 rows=7171 width=53) (actual time=0.683..14351.062 rows=93702 loops=2)
# 29                                              Filter: ((author IS NOT NULL) AND (author IS NOT NULL) AND (to_tsvector('simple'::regconfig, title) @@ to_tsquery('data'::text)))
# 30                                                                                                                                                Rows Removed by Filter: 1634050
# 31                                                                                                                                           Buffers: shared hit=13728 read=69048
# 32                                                                                                                                                        Planning Time: 0.159 ms
# 33                                                                                                                                                   Execution Time: 20685.651 ms
# EXPLAIN results - after indexing
#                                                                                                                                                                                QUERY PLAN
# 0                                                                                      Limit  (cost=94170.74..94170.77 rows=10 width=61) (actual time=8728.286..8737.278 rows=10 loops=1)
# 1                                                                                                          Buffers: shared hit=688 read=132718 written=15439, temp read=5450 written=7657
# 2                                                                                  ->  Sort  (cost=94170.74..94171.24 rows=200 width=61) (actual time=8728.285..8737.276 rows=10 loops=1)
# 3                                                                                                                                                               Sort Key: (count(*)) DESC
# 4                                                                                                                                               Sort Method: top-N heapsort  Memory: 25kB
# 5                                                                                                          Buffers: shared hit=688 read=132718 written=15439, temp read=5450 written=7657
# 6                                                           ->  Finalize GroupAggregate  (cost=94115.75..94166.42 rows=200 width=61) (actual time=8299.985..8704.307 rows=316323 loops=1)
# 7                                                                                                                                                               Group Key: article.author
# 8                                                                                                          Buffers: shared hit=688 read=132718 written=15439, temp read=5450 written=7657
# 9                                                                      ->  Gather Merge  (cost=94115.75..94162.42 rows=400 width=61) (actual time=8299.979..8633.233 rows=342437 loops=1)
# 10                                                                                                                                                                     Workers Planned: 2
# 11                                                                                                                                                                    Workers Launched: 2
# 12                                                                                                         Buffers: shared hit=684 read=132718 written=15439, temp read=5450 written=7657
# 13                                                                             ->  Sort  (cost=93115.73..93116.23 rows=200 width=61) (actual time=8270.944..8360.528 rows=114146 loops=3)
# 14                                                                                                                                                               Sort Key: article.author
# 15                                                                                                                                              Sort Method: external merge  Disk: 9040kB
# 16                                                                                                         Buffers: shared hit=634 read=132718 written=15439, temp read=5450 written=7657
# 17                                                                                                                                   Worker 0:  Sort Method: external merge  Disk: 8976kB
# 18                                                                                                                                   Worker 1:  Sort Method: external merge  Disk: 9200kB
# 19                                                            ->  Partial HashAggregate  (cost=93106.08..93108.08 rows=200 width=61) (actual time=7794.034..7826.039 rows=114146 loops=3)
# 20                                                                                                                                                              Group Key: article.author
# 21                                                                                                                                   Batches: 5  Memory Usage: 8257kB  Disk Usage: 7304kB
# 22                                                                                                         Buffers: shared hit=392 read=132712 written=15437, temp read=2048 written=4246
# 23                                                                                                                        Worker 0:  Batches: 5  Memory Usage: 8257kB  Disk Usage: 7288kB
# 24                                                                                                                        Worker 1:  Batches: 5  Memory Usage: 8257kB  Disk Usage: 7328kB
# 25                                                                    ->  Parallel Append  (cost=137.04..93034.53 rows=14310 width=53) (actual time=16.213..7741.747 rows=121246 loops=3)
# 26                                                                                                                                      Buffers: shared hit=353 read=132673 written=15437
# 27                                                  ->  Parallel Bitmap Heap Scan on article  (cost=137.34..46986.11 rows=7139 width=53) (actual time=7.856..3852.324 rows=58778 loops=3)
# 28                                                                                                    Recheck Cond: (to_tsvector('simple'::regconfig, title) @@ to_tsquery('data'::text))
# 29                                                                                                                                                  Rows Removed by Index Recheck: 398145
# 30                                                                                                                                Filter: ((author IS NOT NULL) AND (author IS NOT NULL))
# 31                                                                                                                                                            Rows Removed by Filter: 345
# 32                                                                                                                                                     Heap Blocks: exact=5803 lossy=5465
# 33                                                                                                                                        Buffers: shared hit=161 read=67078 written=4996
# 34                                                    ->  Bitmap Index Scan on idx_title_article  (cost=0.00..133.06 rows=17342 width=0) (actual time=19.914..19.914 rows=177369 loops=1)
# 35                                                                                                      Index Cond: (to_tsvector('simple'::regconfig, title) @@ to_tsquery('data'::text))
# 36                                                                                                                                             Buffers: shared hit=152 read=45 written=23
# 37                                           ->  Parallel Bitmap Heap Scan on inproceedings  (cost=137.04..45976.87 rows=7171 width=53) (actual time=12.600..5823.741 rows=93702 loops=2)
# 38                                                                                                    Recheck Cond: (to_tsvector('simple'::regconfig, title) @@ to_tsquery('data'::text))
# 39                                                                                                                                                  Rows Removed by Index Recheck: 643606
# 40                                                                                                                                Filter: ((author IS NOT NULL) AND (author IS NOT NULL))
# 41                                                                                                                                                             Rows Removed by Filter: 57
# 42                                                                                                                                                   Heap Blocks: exact=16376 lossy=16619
# 43                                                                                                                                       Buffers: shared hit=192 read=65595 written=10441
# 44                                              ->  Bitmap Index Scan on idx_title_inproceedings  (cost=0.00..132.74 rows=17278 width=0) (actual time=18.818..18.818 rows=187518 loops=1)
# 45                                                                                                      Index Cond: (to_tsvector('simple'::regconfig, title) @@ to_tsquery('data'::text))
# 46                                                                                                                                                Buffers: shared hit=29 read=9 written=9
# 47                                                                                                                                                                              Planning:
# 48                                                                                                                                    Buffers: shared hit=32 read=12 dirtied=2 written=12
# 49                                                                                                                                                                Planning Time: 0.950 ms
# 50                                                                                                                                                            Execution Time: 8739.409 ms

# %% [markdown]
# ##### Question 5:
#
# <a href="https://github.com/andrewcockerill/springboard_06_sql_tuning/blob/main/src/sql_tuning_testing.sql#L204">SQL Code</a>
#
# Here, indices were created for the <tt>booktitle</tt> column in both the <tt>proceedings</tt> and <tt>inproceedings</tt> tables to assist with the join between these two. This resulted in a savings of ~ 1000 ms.

# %%
indexing_experiment('P5')
# Out:
# Write a SQL query to find the names of all conferences, happening in June, where the proceedings contain more than 100 publications.
#
#
# Query Result (First 5 rows)
#                                                                                                                                                                                                                                                      title  \
# 0                                                                                                                                                                 10th Asian Control Conference, ASCC 2015, Kota Kinabalu, Malaysia, May 31 - June 3, 2015
# 1                                      10th IAPR International Conference on Pattern Recognition, Conference A: Computer Vision & Conference B Pattern recognition systems and applications, ICPR 1990, Atlantic City, NJ, USA, 16-21 June, 1990, Volume 1
# 2  10th IAPR International Conference on Pattern Recognition, Conference C: image, speech, and signal processing, and Conference D: computer architecture for vision in pattern recognition, ICPR 1990, Atlantic City, NJ, USA, 16-21 June, 1990, Volume 2
# 3                                                                                                                  10th IEEE International Conference on Computer and Information Technology, CIT 2010, Bradford, West Yorkshire, UK, June 29-July 1, 2010
# 4                                                                                                                                               10th IEEE International Conference on Control and Automation, ICCA 2013, Hangzhou, China, June 12-14, 2013
#
#    papers
# 0     541
# 1     194
# 2     121
# 3     461
# 4     346
# EXPLAIN results - before indexing
#                                                                                                                                                                        QUERY PLAN
# 0                                                                           Limit  (cost=160368.62..160375.31 rows=10 width=149) (actual time=1333.276..1387.362 rows=10 loops=1)
# 1                                                                                                              Buffers: shared hit=2242 read=82541, temp read=15025 written=21392
# 2                                                     ->  Finalize GroupAggregate  (cost=160368.62..160433.43 rows=97 width=149) (actual time=1333.275..1387.360 rows=10 loops=1)
# 3                                                                                                                                                              Group Key: a.title
# 4                                                                                                                                                       Filter: (count(*) >= 100)
# 5                                                                                                                                                      Rows Removed by Filter: 34
# 6                                                                                                              Buffers: shared hit=2242 read=82541, temp read=15025 written=21392
# 7                                                               ->  Gather Merge  (cost=160368.62..160428.34 rows=291 width=149) (actual time=1332.817..1387.342 rows=45 loops=1)
# 8                                                                                                                                                              Workers Planned: 1
# 9                                                                                                                                                             Workers Launched: 1
# 10                                                                                                             Buffers: shared hit=2242 read=82541, temp read=15025 written=21392
# 11                                                    ->  Partial GroupAggregate  (cost=159368.61..159395.59 rows=291 width=149) (actual time=1311.549..1315.959 rows=79 loops=2)
# 12                                                                                                                                                             Group Key: a.title
# 13                                                                                                             Buffers: shared hit=2242 read=82541, temp read=15025 written=21392
# 14                                                                   ->  Sort  (cost=159368.61..159376.64 rows=3209 width=141) (actual time=1311.529..1315.472 rows=6800 loops=2)
# 15                                                                                                                                                              Sort Key: a.title
# 16                                                                                                                                     Sort Method: external merge  Disk: 27896kB
# 17                                                                                                             Buffers: shared hit=2242 read=82541, temp read=15025 written=21392
# 18                                                                                                                          Worker 0:  Sort Method: external merge  Disk: 29056kB
# 19                                                    ->  Parallel Hash Join  (cost=125632.85..159181.72 rows=3209 width=141) (actual time=961.669..1083.232 rows=215105 loops=2)
# 20                                                                                                                 Hash Cond: ((a.booktitle = b.booktitle) AND (a.year = b.year))
# 21                                                                                                             Buffers: shared hit=2205 read=82541, temp read=14089 written=14256
# 22                                                ->  Parallel Seq Scan on proceedings a  (cost=0.00..19478.68 rows=171 width=156) (actual time=0.740..382.727 rows=3735 loops=2)
# 23                                                                                                  Filter: (to_tsvector('simple'::regconfig, title) @@ to_tsquery('june'::text))
# 24                                                                                                                                                  Rows Removed by Filter: 25327
# 25                                                                                                                                                       Buffers: shared hit=2125
# 26                                                         ->  Parallel Hash  (cost=97004.94..97004.94 rows=1439794 width=13) (actual time=561.305..561.306 rows=1727752 loops=2)
# 27                                                                                                                             Buckets: 262144  Batches: 32  Memory Usage: 7872kB
# 28                                                                                                                          Buffers: shared hit=66 read=82541, temp written=14000
# 29                                        ->  Parallel Seq Scan on inproceedings b  (cost=0.00..97004.94 rows=1439794 width=13) (actual time=0.122..318.681 rows=1727752 loops=2)
# 30                                                                                                                                              Buffers: shared hit=66 read=82541
# 31                                                                                                                                                        Planning Time: 0.452 ms
# 32                                                                                                                                                    Execution Time: 1390.011 ms
# EXPLAIN results - after indexing
#                                                                                                                                                    QUERY PLAN
# 0                                                           Limit  (cost=20493.59..53598.38 rows=10 width=149) (actual time=405.692..419.357 rows=10 loops=1)
# 1                                                                                                                          Buffers: shared hit=2621 read=1718
# 2                                             ->  GroupAggregate  (cost=20493.59..341610.06 rows=97 width=149) (actual time=405.691..419.355 rows=10 loops=1)
# 3                                                                                                                                          Group Key: a.title
# 4                                                                                                                                   Filter: (count(*) >= 100)
# 5                                                                                                                                  Rows Removed by Filter: 34
# 6                                                                                                                          Buffers: shared hit=2621 read=1718
# 7                                            ->  Nested Loop  (cost=20493.59..341579.15 rows=5455 width=141) (actual time=404.713..419.010 rows=3958 loops=1)
# 8                                                                                                                          Buffers: shared hit=2621 read=1718
# 9                                               ->  Gather Merge  (cost=20485.03..20518.19 rows=291 width=156) (actual time=404.633..408.003 rows=48 loops=1)
# 10                                                                                                                                         Workers Planned: 1
# 11                                                                                                                                        Workers Launched: 1
# 12                                                                                                                                   Buffers: shared hit=2177
# 13                                                     ->  Sort  (cost=19485.02..19485.45 rows=171 width=156) (actual time=394.016..394.025 rows=214 loops=2)
# 14                                                                                                                                          Sort Key: a.title
# 15                                                                                                                      Sort Method: quicksort  Memory: 787kB
# 16                                                                                                                                   Buffers: shared hit=2177
# 17                                                                                                           Worker 0:  Sort Method: quicksort  Memory: 754kB
# 18                            ->  Parallel Seq Scan on proceedings a  (cost=0.00..19478.68 rows=171 width=156) (actual time=0.960..379.720 rows=3735 loops=2)
# 19                                                                              Filter: (to_tsvector('simple'::regconfig, title) @@ to_tsquery('june'::text))
# 20                                                                                                                              Rows Removed by Filter: 25327
# 21                                                                                                                                   Buffers: shared hit=2140
# 22                                  ->  Bitmap Heap Scan on inproceedings b  (cost=8.56..1103.21 rows=9 width=13) (actual time=0.043..0.222 rows=82 loops=48)
# 23                                                                                                                    Recheck Cond: (a.booktitle = booktitle)
# 24                                                                                                                                    Filter: (year = a.year)
# 25                                                                                                                                Rows Removed by Filter: 800
# 26                                                                                                                                    Heap Blocks: exact=1987
# 27                                                                                                                          Buffers: shared hit=444 read=1718
# 28                      ->  Bitmap Index Scan on idx_booktitle_inproceedings  (cost=0.00..8.56 rows=574 width=0) (actual time=0.024..0.024 rows=913 loops=48)
# 29                                                                                                                      Index Cond: (booktitle = a.booktitle)
# 30                                                                                                                             Buffers: shared hit=82 read=93
# 31                                                                                                                                                  Planning:
# 32                                                                                                                             Buffers: shared hit=38 read=12
# 33                                                                                                                                    Planning Time: 2.045 ms
# 34                                                                                                                                 Execution Time: 419.397 ms

# %%
engine.dispose()

# %% [markdown]
# ##### Commentary on Caching Effects
#
# In the process of running queries against tables, pages can be accessed on disk and are potentially available in the cache/buffer. In the <tt>EXPLAIN</tt> results above, this can be seen when a query pulls from memory (shared hit) versus from disk (read). Any instances where more pages can be accessed from memory will have a positive effect on query run times.
